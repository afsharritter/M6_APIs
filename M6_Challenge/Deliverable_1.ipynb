# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 776

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=62767b31e539b41a2a5236b9d049a549

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        # Append the city information into the city_data list
        city_data.append({'City': city.title(),
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Country': city_country,
                          'Description': city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | merauke
# Processing Record 2 of Set 1 | beringovskiy
# Processing Record 3 of Set 1 | lebu
# Processing Record 4 of Set 1 | ratnapura
# Processing Record 5 of Set 1 | dingle
# Processing Record 6 of Set 1 | batagay
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | rolim de moura
# City not found. Skipping...
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | jalu
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | baturaja
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | belize
# Processing Record 17 of Set 1 | bambous virieux
# Processing Record 18 of Set 1 | kavaratti
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | pangnirtung
# Processing Record 23 of Set 1 | khatanga
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | ust-nera
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | etchoropo
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | sarangani
# Processing Record 30 of Set 1 | rocha
# Processing Record 31 of Set 1 | killybegs
# Processing Record 32 of Set 1 | rancharia
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | lorengau
# Processing Record 35 of Set 1 | kaitangata
# Processing Record 36 of Set 1 | cherskiy
# Processing Record 37 of Set 1 | leningradskiy
# Processing Record 38 of Set 1 | carnarvon
# Processing Record 39 of Set 1 | norman wells
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | flinders
# Processing Record 43 of Set 1 | bilibino
# Processing Record 44 of Set 1 | bara
# Processing Record 45 of Set 1 | sao filipe
# Processing Record 46 of Set 1 | kahului
# Processing Record 47 of Set 1 | faanui
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | la ronge
# Processing Record 50 of Set 1 | barrow
# Processing Record 1 of Set 2 | yichang
# Processing Record 2 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 2 | ponta do sol
# Processing Record 5 of Set 2 | sakata
# Processing Record 6 of Set 2 | dikson
# Processing Record 7 of Set 2 | castro
# Processing Record 8 of Set 2 | horsham
# Processing Record 9 of Set 2 | olafsvik
# Processing Record 10 of Set 2 | manaure
# Processing Record 11 of Set 2 | gazanjyk
# Processing Record 12 of Set 2 | bengkulu
# Processing Record 13 of Set 2 | nikolskoye
# Processing Record 14 of Set 2 | saldanha
# Processing Record 15 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 2 | nizwa
# Processing Record 17 of Set 2 | bredasdorp
# Processing Record 18 of Set 2 | narsaq
# Processing Record 19 of Set 2 | mataura
# Processing Record 20 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 2 | nouakchott
# Processing Record 22 of Set 2 | avarua
# Processing Record 23 of Set 2 | bulolo
# Processing Record 24 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 2 | torbay
# Processing Record 26 of Set 2 | tura
# Processing Record 27 of Set 2 | mishan
# Processing Record 28 of Set 2 | balsas
# Processing Record 29 of Set 2 | ulaangom
# Processing Record 30 of Set 2 | acajutla
# Processing Record 31 of Set 2 | andenes
# Processing Record 32 of Set 2 | mantua
# Processing Record 33 of Set 2 | ban dung
# Processing Record 34 of Set 2 | jamestown
# Processing Record 35 of Set 2 | tasiilaq
# Processing Record 36 of Set 2 | victoria
# Processing Record 37 of Set 2 | berlevag
# Processing Record 38 of Set 2 | jiangyou
# Processing Record 39 of Set 2 | viedma
# Processing Record 40 of Set 2 | puerto ayora
# Processing Record 41 of Set 2 | clyde river
# Processing Record 42 of Set 2 | broome
# Processing Record 43 of Set 2 | sept-iles
# Processing Record 44 of Set 2 | christchurch
# Processing Record 45 of Set 2 | saskylakh
# Processing Record 46 of Set 2 | sur
# Processing Record 47 of Set 2 | lagoa
# Processing Record 48 of Set 2 | les cayes
# Processing Record 49 of Set 2 | salym
# Processing Record 50 of Set 2 | alihe
# Processing Record 1 of Set 3 | vaini
# Processing Record 2 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 3 | airai
# Processing Record 4 of Set 3 | nouadhibou
# Processing Record 5 of Set 3 | bonavista
# Processing Record 6 of Set 3 | mahebourg
# Processing Record 7 of Set 3 | kavieng
# Processing Record 8 of Set 3 | egvekinot
# Processing Record 9 of Set 3 | pevek
# Processing Record 10 of Set 3 | vanimo
# Processing Record 11 of Set 3 | valdosta
# Processing Record 12 of Set 3 | sydney
# Processing Record 13 of Set 3 | the pas
# Processing Record 14 of Set 3 | korla
# Processing Record 15 of Set 3 | ballina
# Processing Record 16 of Set 3 | vila franca do campo
# Processing Record 17 of Set 3 | alice springs
# Processing Record 18 of Set 3 | inuvik
# Processing Record 19 of Set 3 | laguna
# Processing Record 20 of Set 3 | quatre cocos
# Processing Record 21 of Set 3 | omsukchan
# Processing Record 22 of Set 3 | chuy
# Processing Record 23 of Set 3 | atuona
# Processing Record 24 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 3 | gorontalo
# Processing Record 26 of Set 3 | gushikawa
# Processing Record 27 of Set 3 | ogembo
# Processing Record 28 of Set 3 | mar del plata
# Processing Record 29 of Set 3 | ulladulla
# Processing Record 30 of Set 3 | lensk
# Processing Record 31 of Set 3 | hilo
# Processing Record 32 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 33 of Set 3 | coos bay
# Processing Record 34 of Set 3 | praia da vitoria
# Processing Record 35 of Set 3 | trelew
# Processing Record 36 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 3 | vao
# Processing Record 38 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 39 of Set 3 | constitucion
# Processing Record 40 of Set 3 | sucre
# Processing Record 41 of Set 3 | riyadh
# Processing Record 42 of Set 3 | grindavik
# Processing Record 43 of Set 3 | saint george
# Processing Record 44 of Set 3 | beaver falls
# Processing Record 45 of Set 3 | chokurdakh
# Processing Record 46 of Set 3 | okhotsk
# Processing Record 47 of Set 3 | alyangula
# Processing Record 48 of Set 3 | saint-philippe
# Processing Record 49 of Set 3 | guerrero negro
# Processing Record 50 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 4 | katobu
# Processing Record 2 of Set 4 | matamoros
# Processing Record 3 of Set 4 | hofn
# Processing Record 4 of Set 4 | mut
# Processing Record 5 of Set 4 | tilichiki
# Processing Record 6 of Set 4 | tigil
# Processing Record 7 of Set 4 | mabay
# Processing Record 8 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 9 of Set 4 | mehamn
# Processing Record 10 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 4 | hobyo
# Processing Record 12 of Set 4 | aksu
# Processing Record 13 of Set 4 | nago
# Processing Record 14 of Set 4 | itarema
# Processing Record 15 of Set 4 | salalah
# Processing Record 16 of Set 4 | lasa
# Processing Record 17 of Set 4 | yanan
# City not found. Skipping...
# Processing Record 18 of Set 4 | fortuna
# Processing Record 19 of Set 4 | podkletnoye
# Processing Record 20 of Set 4 | maniitsoq
# Processing Record 21 of Set 4 | fukue
# Processing Record 22 of Set 4 | feijo
# Processing Record 23 of Set 4 | ahipara
# Processing Record 24 of Set 4 | bluff
# Processing Record 25 of Set 4 | codrington
# Processing Record 26 of Set 4 | yumen
# Processing Record 27 of Set 4 | burica
# City not found. Skipping...
# Processing Record 28 of Set 4 | east london
# Processing Record 29 of Set 4 | bundaberg
# Processing Record 30 of Set 4 | zhigansk
# Processing Record 31 of Set 4 | pokhara
# Processing Record 32 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 4 | nefteyugansk
# Processing Record 34 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 4 | hammerfest
# Processing Record 36 of Set 4 | hay river
# Processing Record 37 of Set 4 | chazuta
# Processing Record 38 of Set 4 | lakeway
# Processing Record 39 of Set 4 | shimoda
# Processing Record 40 of Set 4 | dunedin
# Processing Record 41 of Set 4 | rawson
# Processing Record 42 of Set 4 | lompoc
# Processing Record 43 of Set 4 | new norfolk
# Processing Record 44 of Set 4 | prainha
# Processing Record 45 of Set 4 | sakaiminato
# Processing Record 46 of Set 4 | pacifica
# Processing Record 47 of Set 4 | lincoln
# Processing Record 48 of Set 4 | hot springs
# Processing Record 49 of Set 4 | portland
# Processing Record 50 of Set 4 | cabedelo
# Processing Record 1 of Set 5 | tuatapere
# Processing Record 2 of Set 5 | plettenberg bay
# Processing Record 3 of Set 5 | tuktoyaktuk
# Processing Record 4 of Set 5 | sayyan
# Processing Record 5 of Set 5 | kijini
# Processing Record 6 of Set 5 | arkhangelsk
# Processing Record 7 of Set 5 | hvide sande
# Processing Record 8 of Set 5 | ribeirao branco
# Processing Record 9 of Set 5 | mendi
# Processing Record 10 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 5 | arraial do cabo
# Processing Record 12 of Set 5 | cabo san lucas
# Processing Record 13 of Set 5 | esperance
# Processing Record 14 of Set 5 | san patricio
# Processing Record 15 of Set 5 | ialibu
# Processing Record 16 of Set 5 | port lincoln
# Processing Record 17 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 5 | jorpeland
# Processing Record 19 of Set 5 | coahuayana
# Processing Record 20 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 5 | ust-kuyga
# Processing Record 23 of Set 5 | husavik
# Processing Record 24 of Set 5 | faya
# Processing Record 25 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 5 | manta
# Processing Record 27 of Set 5 | deputatskiy
# Processing Record 28 of Set 5 | vega de alatorre
# Processing Record 29 of Set 5 | muroto
# Processing Record 30 of Set 5 | kenner
# Processing Record 31 of Set 5 | opuwo
# Processing Record 32 of Set 5 | cockburn town
# Processing Record 33 of Set 5 | thompson
# Processing Record 34 of Set 5 | fairbanks
# Processing Record 35 of Set 5 | pathein
# Processing Record 36 of Set 5 | dinguiraye
# Processing Record 37 of Set 5 | acarau
# Processing Record 38 of Set 5 | lhuntshi
# City not found. Skipping...
# Processing Record 39 of Set 5 | port elizabeth
# Processing Record 40 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 5 | basco
# Processing Record 42 of Set 5 | forbes
# Processing Record 43 of Set 5 | muravlenko
# Processing Record 44 of Set 5 | nanortalik
# Processing Record 45 of Set 5 | chalus
# Processing Record 46 of Set 5 | san quintin
# Processing Record 47 of Set 5 | provideniya
# Processing Record 48 of Set 5 | itoman
# Processing Record 49 of Set 5 | rudbar
# Processing Record 50 of Set 5 | siocon
# Processing Record 1 of Set 6 | sharjah
# Processing Record 2 of Set 6 | xining
# Processing Record 3 of Set 6 | lengshuitan
# Processing Record 4 of Set 6 | cidreira
# Processing Record 5 of Set 6 | axim
# Processing Record 6 of Set 6 | muskogee
# Processing Record 7 of Set 6 | pimentel
# Processing Record 8 of Set 6 | kodiak
# Processing Record 9 of Set 6 | nuuk
# Processing Record 10 of Set 6 | yeniseysk
# Processing Record 11 of Set 6 | koungou
# Processing Record 12 of Set 6 | abalak
# Processing Record 13 of Set 6 | ohara
# Processing Record 14 of Set 6 | san jeronimo
# Processing Record 15 of Set 6 | halifax
# Processing Record 16 of Set 6 | quang ngai
# Processing Record 17 of Set 6 | guanica
# Processing Record 18 of Set 6 | altamira
# Processing Record 19 of Set 6 | qaqortoq
# Processing Record 20 of Set 6 | katsina
# Processing Record 21 of Set 6 | mehran
# Processing Record 22 of Set 6 | the valley
# Processing Record 23 of Set 6 | harper
# Processing Record 24 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 6 | aykhal
# Processing Record 26 of Set 6 | scarborough
# Processing Record 27 of Set 6 | parana
# Processing Record 28 of Set 6 | shache
# Processing Record 29 of Set 6 | kirakira
# Processing Record 30 of Set 6 | port blair
# Processing Record 31 of Set 6 | klaksvik
# Processing Record 32 of Set 6 | roald
# Processing Record 33 of Set 6 | cayenne
# Processing Record 34 of Set 6 | kuytun
# Processing Record 35 of Set 6 | port hardy
# Processing Record 36 of Set 6 | atar
# Processing Record 37 of Set 6 | talnakh
# Processing Record 38 of Set 6 | ilulissat
# Processing Record 39 of Set 6 | normandin
# Processing Record 40 of Set 6 | yerbogachen
# Processing Record 41 of Set 6 | marakkanam
# Processing Record 42 of Set 6 | champerico
# Processing Record 43 of Set 6 | piskivka
# Processing Record 44 of Set 6 | sofiysk
# City not found. Skipping...
# Processing Record 45 of Set 6 | dunayivtsi
# City not found. Skipping...
# Processing Record 46 of Set 6 | fort nelson
# Processing Record 47 of Set 6 | marysville
# Processing Record 48 of Set 6 | agirish
# Processing Record 49 of Set 6 | gambela
# Processing Record 50 of Set 6 | tiksi
# Processing Record 1 of Set 7 | ilo
# Processing Record 2 of Set 7 | rolla
# Processing Record 3 of Set 7 | puerto narino
# Processing Record 4 of Set 7 | nerchinskiy zavod
# Processing Record 5 of Set 7 | shitanjing
# Processing Record 6 of Set 7 | ca mau
# Processing Record 7 of Set 7 | waipawa
# Processing Record 8 of Set 7 | mangan
# Processing Record 9 of Set 7 | bethel
# Processing Record 10 of Set 7 | kuruman
# Processing Record 11 of Set 7 | red wing
# Processing Record 12 of Set 7 | ancud
# Processing Record 13 of Set 7 | aklavik
# Processing Record 14 of Set 7 | lamar
# Processing Record 15 of Set 7 | diamantino
# Processing Record 16 of Set 7 | red bank
# Processing Record 17 of Set 7 | aranos
# Processing Record 18 of Set 7 | iqaluit
# Processing Record 19 of Set 7 | whitehorse
# Processing Record 20 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 7 | urubicha
# Processing Record 22 of Set 7 | whyalla
# Processing Record 23 of Set 7 | cam ranh
# Processing Record 24 of Set 7 | araouane
# Processing Record 25 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 7 | caravelas
# Processing Record 27 of Set 7 | cacule
# Processing Record 28 of Set 7 | pombas
# Processing Record 29 of Set 7 | honiara
# Processing Record 30 of Set 7 | pemangkat
# Processing Record 31 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 7 | renqiu
# Processing Record 33 of Set 7 | el tigre
# Processing Record 34 of Set 7 | yaan
# Processing Record 35 of Set 7 | domoni
# Processing Record 36 of Set 7 | puerto escondido
# Processing Record 37 of Set 7 | newcastle
# Processing Record 38 of Set 7 | venado tuerto
# Processing Record 39 of Set 7 | buraydah
# Processing Record 40 of Set 7 | sistranda
# Processing Record 41 of Set 7 | pitimbu
# Processing Record 42 of Set 7 | vila
# Processing Record 43 of Set 7 | beloha
# Processing Record 44 of Set 7 | hasaki
# Processing Record 45 of Set 7 | manokwari
# Processing Record 46 of Set 7 | okha
# Processing Record 47 of Set 7 | gamboula
# Processing Record 48 of Set 7 | urucara
# Processing Record 49 of Set 7 | igarka
# Processing Record 50 of Set 7 | tarauaca
# Processing Record 1 of Set 8 | karabuk
# Processing Record 2 of Set 8 | ondjiva
# Processing Record 3 of Set 8 | pisco
# Processing Record 4 of Set 8 | les escoumins
# Processing Record 5 of Set 8 | pirovskoye
# Processing Record 6 of Set 8 | borogontsy
# Processing Record 7 of Set 8 | puerto madryn
# Processing Record 8 of Set 8 | namatanai
# Processing Record 9 of Set 8 | vila velha
# Processing Record 10 of Set 8 | teya
# Processing Record 11 of Set 8 | gallup
# Processing Record 12 of Set 8 | ketchikan
# Processing Record 13 of Set 8 | agha jari
# City not found. Skipping...
# Processing Record 14 of Set 8 | qujing
# Processing Record 15 of Set 8 | bereda
# Processing Record 16 of Set 8 | henties bay
# Processing Record 17 of Set 8 | meulaboh
# Processing Record 18 of Set 8 | hauterive
# Processing Record 19 of Set 8 | sisimiut
# Processing Record 20 of Set 8 | krasnyy chikoy
# Processing Record 21 of Set 8 | santa maria
# Processing Record 22 of Set 8 | santa luzia
# Processing Record 23 of Set 8 | dudinka
# Processing Record 24 of Set 8 | jertih
# Processing Record 25 of Set 8 | mount isa
# Processing Record 26 of Set 8 | touros
# Processing Record 27 of Set 8 | high rock
# Processing Record 28 of Set 8 | sena madureira
# Processing Record 29 of Set 8 | maceio
# Processing Record 30 of Set 8 | kamina
# Processing Record 31 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 32 of Set 8 | longyearbyen
# Processing Record 33 of Set 8 | rancho palos verdes
# Processing Record 34 of Set 8 | kabanjahe
# Processing Record 35 of Set 8 | haapiti
# Processing Record 36 of Set 8 | paamiut
# Processing Record 37 of Set 8 | melo
# Processing Record 38 of Set 8 | kulhudhuffushi
# Processing Record 39 of Set 8 | pacific grove
# Processing Record 40 of Set 8 | ossora
# Processing Record 41 of Set 8 | omboue
# Processing Record 42 of Set 8 | cap malheureux
# Processing Record 43 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 44 of Set 8 | mersing
# Processing Record 45 of Set 8 | ostrovnoy
# Processing Record 46 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 8 | porosozero
# Processing Record 48 of Set 8 | samarai
# Processing Record 49 of Set 8 | sirajganj
# Processing Record 50 of Set 8 | tezu
# Processing Record 1 of Set 9 | jaciara
# Processing Record 2 of Set 9 | margate
# Processing Record 3 of Set 9 | cruzeiro do sul
# Processing Record 4 of Set 9 | alofi
# Processing Record 5 of Set 9 | lethbridge
# Processing Record 6 of Set 9 | malkerns
# Processing Record 7 of Set 9 | ribeira grande
# Processing Record 8 of Set 9 | padang
# Processing Record 9 of Set 9 | kawambwa
# Processing Record 10 of Set 9 | luderitz
# Processing Record 11 of Set 9 | vanavara
# Processing Record 12 of Set 9 | zhezkazgan
# Processing Record 13 of Set 9 | oranjestad
# Processing Record 14 of Set 9 | black diamond
# Processing Record 15 of Set 9 | college
# Processing Record 16 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 9 | kalmunai
# Processing Record 18 of Set 9 | lokoja
# Processing Record 19 of Set 9 | bay roberts
# Processing Record 20 of Set 9 | kaduna
# Processing Record 21 of Set 9 | coquimbo
# Processing Record 22 of Set 9 | cubuk
# Processing Record 23 of Set 9 | kailua
# Processing Record 24 of Set 9 | vestmannaeyjar
# Processing Record 25 of Set 9 | phuket
# Processing Record 26 of Set 9 | bom jesus
# Processing Record 27 of Set 9 | katangli
# Processing Record 28 of Set 9 | babu
# Processing Record 29 of Set 9 | nalut
# Processing Record 30 of Set 9 | kosonsoy
# Processing Record 31 of Set 9 | onega
# Processing Record 32 of Set 9 | akdagmadeni
# Processing Record 33 of Set 9 | soissons
# Processing Record 34 of Set 9 | predivinsk
# Processing Record 35 of Set 9 | auki
# Processing Record 36 of Set 9 | mackenzie
# Processing Record 37 of Set 9 | sint michiel
# City not found. Skipping...
# Processing Record 38 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 9 | altar
# Processing Record 40 of Set 9 | rasskazovo
# Processing Record 41 of Set 9 | cancun
# Processing Record 42 of Set 9 | richards bay
# Processing Record 43 of Set 9 | santa maria del oro
# Processing Record 44 of Set 9 | zavodouspenskoye
# Processing Record 45 of Set 9 | yar-sale
# Processing Record 46 of Set 9 | imbituba
# Processing Record 47 of Set 9 | sawakin
# Processing Record 48 of Set 9 | grand gaube
# Processing Record 49 of Set 9 | itaituba
# Processing Record 50 of Set 9 | yarada
# Processing Record 1 of Set 10 | anchorage
# Processing Record 2 of Set 10 | half moon bay
# Processing Record 3 of Set 10 | bella union
# Processing Record 4 of Set 10 | imuris
# Processing Record 5 of Set 10 | ubauro
# Processing Record 6 of Set 10 | zhuhai
# Processing Record 7 of Set 10 | havelock
# Processing Record 8 of Set 10 | taoudenni
# Processing Record 9 of Set 10 | oranjemund
# Processing Record 10 of Set 10 | trairi
# Processing Record 11 of Set 10 | leon valley
# Processing Record 12 of Set 10 | gravdal
# Processing Record 13 of Set 10 | batsfjord
# Processing Record 14 of Set 10 | rockport
# Processing Record 15 of Set 10 | sulurpeta
# City not found. Skipping...
# Processing Record 16 of Set 10 | kattivakkam
# Processing Record 17 of Set 10 | mezen
# Processing Record 18 of Set 10 | tanete
# Processing Record 19 of Set 10 | stornoway
# Processing Record 20 of Set 10 | porto walter
# Processing Record 21 of Set 10 | sosnogorsk
# Processing Record 22 of Set 10 | tabou
# Processing Record 23 of Set 10 | sambava
# Processing Record 24 of Set 10 | collie
# Processing Record 25 of Set 10 | port hueneme
# Processing Record 26 of Set 10 | grong
# Processing Record 27 of Set 10 | bilma
# Processing Record 28 of Set 10 | sinnamary
# Processing Record 29 of Set 10 | sakti
# Processing Record 30 of Set 10 | tonantins
# Processing Record 31 of Set 10 | winkler
# Processing Record 32 of Set 10 | fort frances
# Processing Record 33 of Set 10 | katsuura
# Processing Record 34 of Set 10 | cam pha
# City not found. Skipping...
# Processing Record 35 of Set 10 | santa barbara
# Processing Record 36 of Set 10 | panaba
# Processing Record 37 of Set 10 | morgan hill
# Processing Record 38 of Set 10 | poum
# Processing Record 39 of Set 10 | nome
# Processing Record 40 of Set 10 | san clemente
# Processing Record 41 of Set 10 | huntingdon
# Processing Record 42 of Set 10 | apartado
# Processing Record 43 of Set 10 | amahai
# Processing Record 44 of Set 10 | sitka
# Processing Record 45 of Set 10 | seoul
# Processing Record 46 of Set 10 | kruisfontein
# Processing Record 47 of Set 10 | dibulla
# Processing Record 48 of Set 10 | kyzyl-suu
# Processing Record 49 of Set 10 | hamilton
# Processing Record 50 of Set 10 | baherden
# Processing Record 1 of Set 11 | bathsheba
# Processing Record 2 of Set 11 | ust-barguzin
# Processing Record 3 of Set 11 | spencer
# Processing Record 4 of Set 11 | alappuzha
# Processing Record 5 of Set 11 | camana
# Processing Record 6 of Set 11 | vzmorye
# Processing Record 7 of Set 11 | aksha
# Processing Record 8 of Set 11 | nador
# Processing Record 9 of Set 11 | catazaja
# Processing Record 10 of Set 11 | koslan
# Processing Record 11 of Set 11 | griffin
# Processing Record 12 of Set 11 | zhengjiatun
# Processing Record 13 of Set 11 | cabinda
# Processing Record 14 of Set 11 | tacub
# Processing Record 15 of Set 11 | gat
# Processing Record 16 of Set 11 | martapura
# Processing Record 17 of Set 11 | batagay-alyta
# Processing Record 18 of Set 11 | mpika
# Processing Record 19 of Set 11 | magadan
# Processing Record 20 of Set 11 | upata
# Processing Record 21 of Set 11 | obregon
# Processing Record 22 of Set 11 | san pedro
# Processing Record 23 of Set 11 | lysva
# Processing Record 24 of Set 11 | ulu-telyak
# Processing Record 25 of Set 11 | chervishevo
# Processing Record 26 of Set 11 | anadyr
# Processing Record 27 of Set 11 | ughelli
# Processing Record 28 of Set 11 | baruun-urt
# Processing Record 29 of Set 11 | tingo maria
# Processing Record 30 of Set 11 | mayo
# Processing Record 31 of Set 11 | palaikastron
# Processing Record 32 of Set 11 | esmeraldas
# Processing Record 33 of Set 11 | mattawa
# Processing Record 34 of Set 11 | swan hill
# Processing Record 35 of Set 11 | faratsiho
# Processing Record 36 of Set 11 | nipawin
# Processing Record 37 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 38 of Set 11 | aden
# Processing Record 39 of Set 11 | arroyo
# Processing Record 40 of Set 11 | bankura
# Processing Record 41 of Set 11 | pochutla
# Processing Record 42 of Set 11 | mosetse
# Processing Record 43 of Set 11 | isangel
# Processing Record 44 of Set 11 | macau
# Processing Record 45 of Set 11 | westport
# Processing Record 46 of Set 11 | kimberley
# Processing Record 47 of Set 11 | marsabit
# Processing Record 48 of Set 11 | villablino
# Processing Record 49 of Set 11 | fenoarivo
# Processing Record 50 of Set 11 | angelholm
# City not found. Skipping...
# Processing Record 1 of Set 12 | northam
# Processing Record 2 of Set 12 | yining
# Processing Record 3 of Set 12 | farkhor
# Processing Record 4 of Set 12 | anzio
# Processing Record 5 of Set 12 | kandi
# Processing Record 6 of Set 12 | chekhov
# Processing Record 7 of Set 12 | srednekolymsk
# Processing Record 8 of Set 12 | mahibadhoo
# Processing Record 9 of Set 12 | charyshskoye
# Processing Record 10 of Set 12 | manavgat
# Processing Record 11 of Set 12 | mastung
# Processing Record 12 of Set 12 | drumheller
# Processing Record 13 of Set 12 | ngunguru
# Processing Record 14 of Set 12 | boysun
# Processing Record 15 of Set 12 | nyimba
# Processing Record 16 of Set 12 | biltine
# Processing Record 17 of Set 12 | aswan
# Processing Record 18 of Set 12 | geraldton
# Processing Record 19 of Set 12 | saa
# Processing Record 20 of Set 12 | solnechnyy
# Processing Record 21 of Set 12 | chililabombwe
# Processing Record 22 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 12 | lata
# Processing Record 24 of Set 12 | novo aripuana
# Processing Record 25 of Set 12 | marsh harbour
# Processing Record 26 of Set 12 | atambua
# Processing Record 27 of Set 12 | loanda
# Processing Record 28 of Set 12 | ixtapa
# Processing Record 29 of Set 12 | snasa
# Processing Record 30 of Set 12 | gizo
# Processing Record 31 of Set 12 | tawnat
# City not found. Skipping...
# Processing Record 32 of Set 12 | manzil tamim
# City not found. Skipping...
# Processing Record 33 of Set 12 | khasan
# Processing Record 34 of Set 12 | polunochnoye
# Processing Record 35 of Set 12 | miri
# Processing Record 36 of Set 12 | mana
# Processing Record 37 of Set 12 | devrek
# Processing Record 38 of Set 12 | los llanos de aridane
# Processing Record 39 of Set 12 | alpena
# Processing Record 40 of Set 12 | nyurba
# Processing Record 41 of Set 12 | plyussa
# Processing Record 42 of Set 12 | ust-omchug
# Processing Record 43 of Set 12 | inverness
# Processing Record 44 of Set 12 | tawau
# Processing Record 45 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 12 | coihaique
# Processing Record 47 of Set 12 | puerto del rosario
# Processing Record 48 of Set 12 | bubaque
# Processing Record 49 of Set 12 | ayacucho
# Processing Record 50 of Set 12 | jaque
# Processing Record 1 of Set 13 | janauba
# Processing Record 2 of Set 13 | fare
# Processing Record 3 of Set 13 | hadejia
# Processing Record 4 of Set 13 | daru
# Processing Record 5 of Set 13 | izhma
# Processing Record 6 of Set 13 | senanga
# Processing Record 7 of Set 13 | la paz
# Processing Record 8 of Set 13 | quchan
# Processing Record 9 of Set 13 | keskin
# Processing Record 10 of Set 13 | katete
# Processing Record 11 of Set 13 | tocopilla
# Processing Record 12 of Set 13 | khartoum
# Processing Record 13 of Set 13 | mastic beach
# Processing Record 14 of Set 13 | kalemie
# Processing Record 15 of Set 13 | sorland
# Processing Record 16 of Set 13 | avera
# Processing Record 17 of Set 13 | katy
# Processing Record 18 of Set 13 | aketi
# Processing Record 19 of Set 13 | bima
# Processing Record 20 of Set 13 | koundara
# Processing Record 21 of Set 13 | santa isabel do rio negro
# Processing Record 22 of Set 13 | oistins
# Processing Record 23 of Set 13 | pingliang
# Processing Record 24 of Set 13 | tagusao
# Processing Record 25 of Set 13 | orsha
# Processing Record 26 of Set 13 | manzil salim
# Processing Record 27 of Set 13 | horta
# Processing Record 28 of Set 13 | bari
# Processing Record 29 of Set 13 | alto araguaia
# Processing Record 30 of Set 13 | bandar
# Processing Record 31 of Set 13 | abha
# Processing Record 32 of Set 13 | vincennes
# Processing Record 33 of Set 13 | southampton
# Processing Record 34 of Set 13 | mahanoro
# Processing Record 35 of Set 13 | inta
# Processing Record 36 of Set 13 | sovetskiy
# Processing Record 37 of Set 13 | zalantun
# Processing Record 38 of Set 13 | humaita
# Processing Record 39 of Set 13 | goure
# Processing Record 40 of Set 13 | bohuslav
# Processing Record 41 of Set 13 | maracacume
# Processing Record 42 of Set 13 | charters towers
# Processing Record 43 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 44 of Set 13 | saint-augustin
# Processing Record 45 of Set 13 | havoysund
# Processing Record 46 of Set 13 | saint-pierre
# Processing Record 47 of Set 13 | inhambane
# Processing Record 48 of Set 13 | vieques
# Processing Record 49 of Set 13 | dianopolis
# City not found. Skipping...
# Processing Record 50 of Set 13 | kadhan
# Processing Record 1 of Set 14 | gribanovskiy
# Processing Record 2 of Set 14 | pimenteiras
# Processing Record 3 of Set 14 | severo-kurilsk
# Processing Record 4 of Set 14 | ambilobe
# Processing Record 5 of Set 14 | sikeston
# Processing Record 6 of Set 14 | aakirkeby
# City not found. Skipping...
# Processing Record 7 of Set 14 | luorong
# Processing Record 8 of Set 14 | bangkalan
# Processing Record 9 of Set 14 | mount gambier
# Processing Record 10 of Set 14 | yakeshi
# Processing Record 11 of Set 14 | kondinskoye
# Processing Record 12 of Set 14 | mersin
# Processing Record 13 of Set 14 | kawalu
# Processing Record 14 of Set 14 | fethiye
# Processing Record 15 of Set 14 | daytona beach
# Processing Record 16 of Set 14 | yantzaza
# Processing Record 17 of Set 14 | quilmana
# Processing Record 18 of Set 14 | ponnani
# Processing Record 19 of Set 14 | wanxian
# Processing Record 20 of Set 14 | praya
# Processing Record 21 of Set 14 | ust-tarka
# Processing Record 22 of Set 14 | norrtalje
# Processing Record 23 of Set 14 | tiznit
# Processing Record 24 of Set 14 | pringsewu
# Processing Record 25 of Set 14 | cartago
# Processing Record 26 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 27 of Set 14 | libreville
# Processing Record 28 of Set 14 | baculin
# Processing Record 29 of Set 14 | severnyy
# Processing Record 30 of Set 14 | sao jose da coroa grande
# Processing Record 31 of Set 14 | garowe
# Processing Record 32 of Set 14 | kyra
# Processing Record 33 of Set 14 | san cristobal
# Processing Record 34 of Set 14 | kosa
# Processing Record 35 of Set 14 | alta floresta
# Processing Record 36 of Set 14 | houston
# Processing Record 37 of Set 14 | luwuk
# Processing Record 38 of Set 14 | nelson bay
# Processing Record 39 of Set 14 | oktyabrskoye
# Processing Record 40 of Set 14 | narasannapeta
# Processing Record 41 of Set 14 | mega
# Processing Record 42 of Set 14 | marienburg
# Processing Record 43 of Set 14 | kidal
# Processing Record 44 of Set 14 | galway
# Processing Record 45 of Set 14 | sivaki
# Processing Record 46 of Set 14 | harindanga
# Processing Record 47 of Set 14 | ahumada
# City not found. Skipping...
# Processing Record 48 of Set 14 | inirida
# Processing Record 49 of Set 14 | nemuro
# Processing Record 50 of Set 14 | bambanglipuro
# Processing Record 1 of Set 15 | mandalgovi
# Processing Record 2 of Set 15 | rennes
# Processing Record 3 of Set 15 | muzhi
# Processing Record 4 of Set 15 | katherine
# Processing Record 5 of Set 15 | elliot lake
# Processing Record 6 of Set 15 | bowen
# Processing Record 7 of Set 15 | novoagansk
# Processing Record 8 of Set 15 | madison
# Processing Record 9 of Set 15 | saint-georges
# Processing Record 10 of Set 15 | vera cruz
# Processing Record 11 of Set 15 | dabra
# Processing Record 12 of Set 15 | vad
# Processing Record 13 of Set 15 | candawaga
# City not found. Skipping...
# Processing Record 14 of Set 15 | gordeyevka
# Processing Record 15 of Set 15 | tinjah
# City not found. Skipping...
# Processing Record 16 of Set 15 | honningsvag
# Processing Record 17 of Set 15 | hunterville
# Processing Record 18 of Set 15 | foumban
# Processing Record 19 of Set 15 | camargo
# Processing Record 20 of Set 15 | seymchan
# Processing Record 21 of Set 15 | taksimo
# Processing Record 22 of Set 15 | asfi
# Processing Record 23 of Set 15 | rio verde de mato grosso
# Processing Record 24 of Set 15 | akdepe
# Processing Record 25 of Set 15 | monte cristi
# City not found. Skipping...
# Processing Record 26 of Set 15 | tiarei
# Processing Record 27 of Set 15 | zaykovo
# Processing Record 28 of Set 15 | denpasar
# Processing Record 29 of Set 15 | frontignan
# Processing Record 30 of Set 15 | sheridan
# Processing Record 31 of Set 15 | stoyba
# City not found. Skipping...
# Processing Record 32 of Set 15 | sao joao da barra
# Processing Record 33 of Set 15 | hit
# Processing Record 34 of Set 15 | mackay
# Processing Record 35 of Set 15 | le port
# Processing Record 36 of Set 15 | aloleng
# Processing Record 37 of Set 15 | zhangye
# Processing Record 38 of Set 15 | boa vista
# Processing Record 39 of Set 15 | hambantota
# Processing Record 40 of Set 15 | shenjiamen
# Processing Record 41 of Set 15 | yatou
# Processing Record 42 of Set 15 | sao sepe
# Processing Record 43 of Set 15 | gunnedah
# Processing Record 44 of Set 15 | anori
# Processing Record 45 of Set 15 | bandarbeyla
# Processing Record 46 of Set 15 | mombetsu
# Processing Record 47 of Set 15 | sarankhola
# Processing Record 48 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 15 | mareeba
# Processing Record 50 of Set 15 | marzuq
# Processing Record 1 of Set 16 | novyy svit
# Processing Record 2 of Set 16 | bengkalis
# City not found. Skipping...
# Processing Record 3 of Set 16 | general pico
# Processing Record 4 of Set 16 | ardahan
# Processing Record 5 of Set 16 | novopokrovka
# Processing Record 6 of Set 16 | arman
# Processing Record 7 of Set 16 | galle
# Processing Record 8 of Set 16 | pozo colorado
# Processing Record 9 of Set 16 | cotonou
# Processing Record 10 of Set 16 | najran
# Processing Record 11 of Set 16 | mancio lima
# Processing Record 12 of Set 16 | nuevo progreso
# Processing Record 13 of Set 16 | kijaba
# City not found. Skipping...
# Processing Record 14 of Set 16 | skalistyy
# City not found. Skipping...
# Processing Record 15 of Set 16 | jiamusi
# Processing Record 16 of Set 16 | isiro
# Processing Record 17 of Set 16 | helong
# Processing Record 18 of Set 16 | marawi
# Processing Record 19 of Set 16 | anacortes
# Processing Record 20 of Set 16 | biloela
# Processing Record 21 of Set 16 | santander
# Processing Record 22 of Set 16 | mandera
# Processing Record 23 of Set 16 | westerland
# Processing Record 24 of Set 16 | iquique
# Processing Record 25 of Set 16 | monte patria
# Processing Record 26 of Set 16 | tual
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 717

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Merauke  -8.4667  140.3333     85.68        61         100
# 1  Beringovskiy  63.0500  179.3167     19.29        58          11
# 2          Lebu -37.6167  -73.6500     53.58        94         100
# 3     Ratnapura   6.6828   80.3992     88.21        48           3
# 4        Dingle  10.9995  122.6711     73.80        98         100
# 5       Batagay  67.6333  134.6333     11.14        90          72
# 6       Rikitea -23.1203 -134.9692     73.13        76          91
# 7    Georgetown   5.4112  100.3354     85.93        76          20
# 8  Punta Arenas -53.1500  -70.9167     41.11        75          75
# 9          Jalu  29.0331   21.5482     64.78        51           0
#
#    Wind Speed Country      Description
# 0       13.15      ID  overcast clouds
# 1        9.22      RU       few clouds
# 2        9.89      CL    moderate rain
# 3        4.99      LK        clear sky
# 4        5.86      PH    moderate rain
# 5        3.56      RU    broken clouds
# 6       13.76      PF  overcast clouds
# 7        5.99      MY       light rain
# 8       16.11      CL    broken clouds
# 9        7.23      LY        clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ['City', 'Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed', 'Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Merauke      ID  -8.4667  140.3333     85.68        61         100
# 1  Beringovskiy      RU  63.0500  179.3167     19.29        58          11
# 2          Lebu      CL -37.6167  -73.6500     53.58        94         100
# 3     Ratnapura      LK   6.6828   80.3992     88.21        48           3
# 4        Dingle      PH  10.9995  122.6711     73.80        98         100
#
#    Wind Speed      Description
# 0       13.15  overcast clouds
# 1        9.22       few clouds
# 2        9.89    moderate rain
# 3        4.99        clear sky
# 4        5.86    moderate rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = 'Weather_Database/cities.csv'

#export the city_data into a CSV.
city_data_df.to_csv(output_data_file, index_label='City_ID')
